# %%
import random


# A agent at any time has the following state
#  pos : int
#  health : int (>=0)
class AgentState:
    def __init__(self, health):
        self.health = health

# A game has the following state at any time. The state is visiable to both agents
#  state of agent_0
#  state of agent_1
class GameState:                
    def __init__(self, agent_0_state, agent_1_state, agents_distance):
        self.agents = [agent_0_state, agent_1_state]
        self.agents_distance = agents_distance
        
    def __str__(self):
     return str(self.agents_distance) + "," + str(self.agents[0].health) + ","  + str(self.agents[1].health)

# at any time in a game, a agent can take one of the following actions
class GameAction:
    MOVETOWARDS = "MOVETOWARDS"
    MOVEAWAY = "MOVEAWAY"
    ATTACK = "ATTACK"
        
# The simulator manges the following
#   the game state at any time
#   reward judgment
class GameSimulator:
    def __init__(self):
        # init the game state (start of a game)
        self.init_health = 3
        self.miss_rate = 0.1
        self.move_speed = 1
        self.attack_power = 1
        self.attack_range = 1
        self.final_award = 100
        self.init_agents_distance = 2
        self.max_agents_distance = 5
        
        agent_0 = AgentState(self.init_health)
        agent_1 = AgentState(self.init_health)
        self.state = GameState(agent_0, agent_1, self.init_agents_distance)

    
    def move_agent(self, agent_idx, agent_action):
        # no health no action
        if self.state.agents[agent_idx].health <= 0:
            return
        
        opponent_idx = (agent_idx + 1) % 2
        if agent_action == GameAction.MOVETOWARDS: # cannot run into each other
            self.state.agents_distance = max(1, self.state.agents_distance - self.move_speed)
        
        if agent_action == GameAction.MOVEAWAY: # cannot be more than max_agents_distance apart
            self.state.agents_distance = min(self.state.agents_distance + self.move_speed, self.max_agents_distance)
                
        # [Q] should we reward for being closer to the opponent ? 
    
    def attack_agent(self, agent_idx, agent_action):
        # no health no action
        if self.state.agents[agent_idx].health <= 0:
            return
        
        opponent_idx = (agent_idx + 1) % 2
        
        if agent_action == GameAction.ATTACK:
            # there is a change to miss the hit
            hit =  0 if random.random() < self.miss_rate else 1
            
            # attack is only valid if the two agents are within attack range
            if self.state.agents_distance <= self.attack_range:
                self.state.agents[opponent_idx].health = self.state.agents[opponent_idx].health - hit * self.attack_power
                
                # if the opponent still has positive health, reward by attack power
                # if the opponent has zero or negative health, reward by final reward
                if self.state.agents[opponent_idx].health > 0:
                    return hit * self.attack_power
                else:
                    return self.final_award
        
        # no attack action return 0
        return 0
    

    # consider the action of both agent_0 and agent_1, decide the reward to each
    def take_action(self, action_0, action_1):
        reward_0 = 0
        reward_1 = 0
      
        # first make the move update
        who_moves_first = 0 if random.random() < 0.5 else 1
        
        if who_moves_first == 0: # agent_0 moves first
            self.move_agent(0, action_0)
            self.move_agent(1, action_1)
        else:
            self.move_agent(1, action_1)
            self.move_agent(0, action_0)
        
      
        # then make the attack update
        gain_0 = 0
        gain_1 = 0
        
        who_attacks_first = 0 if random.random() < 0.5 else 1
        if who_attacks_first == 0: # agent_0 attacks first
            gain_0 = self.attack_agent(0, action_0)
            gain_1 = self.attack_agent(1, action_1)
        else:
            gain_1 = self.attack_agent(1, action_1)
            gain_0 = self.attack_agent(0, action_0)
        
        # if the agent still has positive health, reward is the attack result
        # otherwise, the reward is -1 * final_reward
        reward_0 = gain_0 if self.state.agents[0].health > 0 else -1 * gain_1
        reward_1 = gain_1 if self.state.agents[1].health > 0 else -1 * gain_0
        
        return self.state, reward_0, reward_1

    def reset(self):
        # Reset state 
        agent_0 = AgentState(self.init_health)
        agent_1 = AgentState(self.init_health)
        self.state = GameState(agent_0, agent_1, self.init_agents_distance)
        
        return self.state
    
    def is_finished(self):
        # finished when one agent is 0 health
        # return the winner
        if self.state.agents[0].health <= 0:
            return 1
        
        if self.state.agents[1].health <= 0:
            return 0
        
        return -1

# %%
import random
import numpy as np

class AgentClass1:
    def __init__(self, learning_rate=0.2, discount=0.95, exploration_rate=1.0):
        self.learning_rate = learning_rate # How much we appreciate new q-value over current
        self.discount = discount # How much we appreciate future reward over current
        self.init_exploration_rate = exploration_rate # Initial exploration rate
        self.exploration_rate = self.init_exploration_rate
        self.exploration_decay = 0.01 # Shift from exploration to explotation

        self.action_list = [GameAction.MOVETOWARDS, GameAction.MOVEAWAY, GameAction.ATTACK]
        
        # q_dict that keeps the reward for each key
        # the key is composed of "agents_distance, agent_0_health, agent_1_health"
        # the value is a array of size len(self.action_list) represents the reward of each action
        self.q_dict = {"init" : [0]*len(self.action_list)}
        


    def get_next_action(self, game_state):
        state_key = str(game_state)
        
        if state_key not in self.q_dict:  # always init the state if not init yet
            self.q_dict[state_key] = [0]*len(self.action_list)
                
        if random.random() > self.exploration_rate: # Explore (gamble) or exploit (greedy)
            return self.greedy_action(game_state)
        else:
            return self.random_action()

    def greedy_action(self, game_state):
        state_key = str(game_state)
        
        # randomly pick one from the actions with max reward
        max_reward = max(self.q_dict[state_key])
        indices = [i for i, x in enumerate(self.q_dict[state_key]) if x == max_reward]
        action_idx =random.randrange(len(indices))
            
        return self.action_list[indices[action_idx]]   
            

    def random_action(self):
        return self.action_list[random.randrange(len(self.action_list))]
    

    def update(self, cur_state, new_state, action, reward):
        cur_state_idx = str(cur_state)
        new_state_idx = str(new_state)
        action_idx = self.action_list.index(action)
        
        # cur Q-dict value
        cur_value = self.q_dict[cur_state_idx][action_idx]
        
        # What would be our best next action?
        if new_state_idx not in self.q_dict: # if future state does not init yet, init it
            self.q_dict[new_state_idx] = [0]*len(self.action_list)
            
        future_reward = max(self.q_dict[new_state_idx])
        
        # Main Q-table updating algorithm
        new_value = cur_value + self.learning_rate * (reward + self.discount * future_reward - cur_value)
        self.q_dict[cur_state_idx][action_idx] = new_value

        # Finally shift our exploration_rate toward zero (less gambling)
        if self.exploration_rate > 0:
            self.exploration_rate *= (1 - self.exploration_decay)
            
    def reset(self):
        self.exploration_rate = self.init_exploration_rate
        
    def dump_qtable(self, file_name):
        with open(file_name, 'w') as outfile:
            json.dump(self.q_dict, outfile)
    
    def load_qtable(self, file_name):
        with open(file_name) as json_file: 
            self.q_dict = json.load(json_file)

# %%
import random
import json
import time
import copy

# parse arguments
iterations = 10000
    
# setup simulation
master = GameSimulator()
master.reset()
total_reward = 0 # Score keeping
    
# setup agents
agent_0 = AgentClass1()
agent_1 = AgentClass1()

agent_0_win = 0
agent_1_win = 0

# main loop
for step in range(iterations):
    old_state = copy.deepcopy(master.state) # Store current state
    
    action_0 = agent_0.get_next_action(old_state) # Query agent for the next action
    action_1 = agent_1.get_next_action(old_state)
        
    new_state, reward_0, reward_1 = master.take_action(action_0, action_1) # Take action, get new state and reward
        
    agent_0.update(old_state, new_state, action_0, reward_0) 
    agent_1.update(old_state, new_state, action_1, reward_1) 

    total_reward += max(reward_0, reward_1) # Keep score
    
    winner = master.is_finished()
    
    if winner >= 0 :  # game is finished with winner
        if winner == 0:
            agent_0_win += 1
        if winner == 1:
            agent_1_win += 1
        
        # reset to start a new game
        master.reset()
        agent_0.reset()
        agent_1.reset()
            
    
    if step % 100 == 0 or step == iterations - 1 :
        print(json.dumps({'i': step, "o_state": str(old_state), "n_state": str(new_state), "a0": action_0, "a1": action_1, 't_re': total_reward, '0_win': agent_0_win, '1_win': agent_1_win}))

    time.sleep(0.0001) # Avoid spamming stdout too fast!
# Out:
# {"i": 0, "o_state": "2,3,3", "n_state": "2,3,3", "a0": "MOVETOWARDS", "a1": "MOVEAWAY", "t_re": 0, "0_win": 0, "1_win": 0}
# {"i": 100, "o_state": "2,3,2", "n_state": "2,3,2", "a0": "ATTACK", "a1": "ATTACK", "t_re": 309, "0_win": 0, "1_win": 3}
# {"i": 200, "o_state": "4,3,3", "n_state": "3,3,3", "a0": "MOVETOWARDS", "a1": "ATTACK", "t_re": 514, "0_win": 1, "1_win": 4}
# {"i": 300, "o_state": "5,2,1", "n_state": "5,2,1", "a0": "MOVEAWAY", "a1": "MOVEAWAY", "t_re": 723, "0_win": 1, "1_win": 6}
# {"i": 400, "o_state": "4,3,3", "n_state": "5,3,3", "a0": "ATTACK", "a1": "MOVEAWAY", "t_re": 1134, "0_win": 2, "1_win": 9}
# {"i": 500, "o_state": "1,3,2", "n_state": "1,3,2", "a0": "MOVETOWARDS", "a1": "MOVEAWAY", "t_re": 1443, "0_win": 4, "1_win": 10}
# {"i": 600, "o_state": "1,1,3", "n_state": "1,1,3", "a0": "MOVEAWAY", "a1": "MOVETOWARDS", "t_re": 1852, "0_win": 7, "1_win": 11}
# {"i": 700, "o_state": "3,3,1", "n_state": "3,3,1", "a0": "MOVETOWARDS", "a1": "MOVEAWAY", "t_re": 2365, "0_win": 7, "1_win": 16}
# {"i": 800, "o_state": "2,3,3", "n_state": "3,3,3", "a0": "MOVEAWAY", "a1": "ATTACK", "t_re": 2569, "0_win": 7, "1_win": 18}
# {"i": 900, "o_state": "5,2,3", "n_state": "3,2,3", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 2980, "0_win": 9, "1_win": 20}
# {"i": 1000, "o_state": "1,1,3", "n_state": "1,0,3", "a0": "ATTACK", "a1": "ATTACK", "t_re": 3286, "0_win": 10, "1_win": 22}
# {"i": 1100, "o_state": "4,3,3", "n_state": "3,3,3", "a0": "ATTACK", "a1": "MOVETOWARDS", "t_re": 3697, "0_win": 10, "1_win": 26}
# {"i": 1200, "o_state": "2,1,2", "n_state": "1,1,2", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 4009, "0_win": 12, "1_win": 27}
# {"i": 1300, "o_state": "2,3,2", "n_state": "1,3,2", "a0": "ATTACK", "a1": "MOVETOWARDS", "t_re": 4418, "0_win": 13, "1_win": 30}
# {"i": 1400, "o_state": "2,1,1", "n_state": "1,0,1", "a0": "MOVETOWARDS", "a1": "ATTACK", "t_re": 5031, "0_win": 15, "1_win": 34}
# {"i": 1500, "o_state": "4,2,3", "n_state": "5,2,3", "a0": "ATTACK", "a1": "MOVEAWAY", "t_re": 5443, "0_win": 16, "1_win": 37}
# {"i": 1600, "o_state": "4,2,2", "n_state": "4,2,2", "a0": "MOVEAWAY", "a1": "MOVETOWARDS", "t_re": 5853, "0_win": 18, "1_win": 39}
# {"i": 1700, "o_state": "1,2,3", "n_state": "1,2,3", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 6367, "0_win": 20, "1_win": 42}
# {"i": 1800, "o_state": "4,3,2", "n_state": "3,3,2", "a0": "MOVETOWARDS", "a1": "ATTACK", "t_re": 6777, "0_win": 22, "1_win": 44}
# {"i": 1900, "o_state": "1,1,2", "n_state": "2,1,2", "a0": "MOVEAWAY", "a1": "ATTACK", "t_re": 7087, "0_win": 22, "1_win": 47}
# {"i": 2000, "o_state": "3,1,2", "n_state": "3,1,2", "a0": "ATTACK", "a1": "ATTACK", "t_re": 7599, "0_win": 24, "1_win": 50}
# {"i": 2100, "o_state": "1,2,3", "n_state": "2,2,3", "a0": "ATTACK", "a1": "MOVEAWAY", "t_re": 8008, "0_win": 26, "1_win": 52}
# {"i": 2200, "o_state": "2,2,2", "n_state": "3,2,2", "a0": "MOVEAWAY", "a1": "ATTACK", "t_re": 8523, "0_win": 30, "1_win": 53}
# {"i": 2300, "o_state": "2,3,3", "n_state": "4,3,3", "a0": "MOVEAWAY", "a1": "MOVEAWAY", "t_re": 8933, "0_win": 33, "1_win": 54}
# {"i": 2400, "o_state": "2,3,3", "n_state": "2,3,3", "a0": "MOVETOWARDS", "a1": "MOVEAWAY", "t_re": 9448, "0_win": 35, "1_win": 57}
# {"i": 2500, "o_state": "5,3,3", "n_state": "5,3,3", "a0": "ATTACK", "a1": "ATTACK", "t_re": 9754, "0_win": 37, "1_win": 58}
# {"i": 2600, "o_state": "3,1,1", "n_state": "1,1,1", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 10167, "0_win": 39, "1_win": 60}
# {"i": 2700, "o_state": "3,3,3", "n_state": "1,3,3", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 10577, "0_win": 39, "1_win": 64}
# {"i": 2800, "o_state": "4,3,3", "n_state": "4,3,3", "a0": "MOVEAWAY", "a1": "MOVETOWARDS", "t_re": 10988, "0_win": 42, "1_win": 65}
# {"i": 2900, "o_state": "4,2,2", "n_state": "4,2,2", "a0": "ATTACK", "a1": "ATTACK", "t_re": 11299, "0_win": 43, "1_win": 67}
# {"i": 3000, "o_state": "1,2,2", "n_state": "2,2,2", "a0": "ATTACK", "a1": "MOVEAWAY", "t_re": 11815, "0_win": 47, "1_win": 68}
# {"i": 3100, "o_state": "1,2,3", "n_state": "1,1,2", "a0": "ATTACK", "a1": "ATTACK", "t_re": 12224, "0_win": 48, "1_win": 71}
# {"i": 3200, "o_state": "2,1,2", "n_state": "3,1,2", "a0": "MOVEAWAY", "a1": "ATTACK", "t_re": 12634, "0_win": 50, "1_win": 73}
# {"i": 3300, "o_state": "2,3,3", "n_state": "1,2,3", "a0": "MOVETOWARDS", "a1": "ATTACK", "t_re": 13145, "0_win": 53, "1_win": 75}
# {"i": 3400, "o_state": "2,2,1", "n_state": "2,2,1", "a0": "ATTACK", "a1": "ATTACK", "t_re": 13456, "0_win": 53, "1_win": 78}
# {"i": 3500, "o_state": "1,3,3", "n_state": "2,3,3", "a0": "MOVETOWARDS", "a1": "MOVEAWAY", "t_re": 13968, "0_win": 55, "1_win": 81}
# {"i": 3600, "o_state": "5,3,3", "n_state": "4,3,3", "a0": "MOVETOWARDS", "a1": "ATTACK", "t_re": 14275, "0_win": 57, "1_win": 82}
# {"i": 3700, "o_state": "2,2,2", "n_state": "3,2,2", "a0": "MOVEAWAY", "a1": "ATTACK", "t_re": 14586, "0_win": 58, "1_win": 84}
# {"i": 3800, "o_state": "1,3,2", "n_state": "1,2,2", "a0": "MOVETOWARDS", "a1": "ATTACK", "t_re": 14894, "0_win": 60, "1_win": 85}
# {"i": 3900, "o_state": "4,3,3", "n_state": "2,3,3", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 15201, "0_win": 62, "1_win": 86}
# {"i": 4000, "o_state": "3,3,3", "n_state": "3,3,3", "a0": "MOVEAWAY", "a1": "MOVETOWARDS", "t_re": 15714, "0_win": 64, "1_win": 89}
# {"i": 4100, "o_state": "1,1,1", "n_state": "2,1,1", "a0": "ATTACK", "a1": "MOVEAWAY", "t_re": 16023, "0_win": 65, "1_win": 91}
# {"i": 4200, "o_state": "2,2,3", "n_state": "2,2,3", "a0": "ATTACK", "a1": "ATTACK", "t_re": 16431, "0_win": 68, "1_win": 92}
# {"i": 4300, "o_state": "2,2,1", "n_state": "1,2,1", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 16845, "0_win": 72, "1_win": 92}
# {"i": 4400, "o_state": "1,3,3", "n_state": "1,2,2", "a0": "ATTACK", "a1": "ATTACK", "t_re": 17254, "0_win": 74, "1_win": 94}
# {"i": 4500, "o_state": "2,3,3", "n_state": "2,3,3", "a0": "ATTACK", "a1": "ATTACK", "t_re": 17664, "0_win": 76, "1_win": 96}
# {"i": 4600, "o_state": "2,3,3", "n_state": "2,3,3", "a0": "ATTACK", "a1": "ATTACK", "t_re": 18076, "0_win": 78, "1_win": 98}
# {"i": 4700, "o_state": "1,3,2", "n_state": "1,3,2", "a0": "ATTACK", "a1": "MOVETOWARDS", "t_re": 18488, "0_win": 82, "1_win": 98}
# {"i": 4800, "o_state": "1,2,3", "n_state": "1,2,3", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 18898, "0_win": 84, "1_win": 100}
# {"i": 4900, "o_state": "2,2,3", "n_state": "3,2,3", "a0": "ATTACK", "a1": "MOVEAWAY", "t_re": 19105, "0_win": 85, "1_win": 101}
# {"i": 5000, "o_state": "5,1,1", "n_state": "5,1,1", "a0": "ATTACK", "a1": "ATTACK", "t_re": 19315, "0_win": 85, "1_win": 103}
# {"i": 5100, "o_state": "1,2,3", "n_state": "1,2,3", "a0": "MOVETOWARDS", "a1": "ATTACK", "t_re": 19623, "0_win": 88, "1_win": 103}
# {"i": 5200, "o_state": "1,1,1", "n_state": "2,1,1", "a0": "MOVEAWAY", "a1": "ATTACK", "t_re": 19833, "0_win": 90, "1_win": 103}
# {"i": 5300, "o_state": "3,2,1", "n_state": "2,2,1", "a0": "MOVETOWARDS", "a1": "ATTACK", "t_re": 20346, "0_win": 92, "1_win": 106}
# {"i": 5400, "o_state": "2,2,2", "n_state": "3,2,2", "a0": "ATTACK", "a1": "MOVEAWAY", "t_re": 20551, "0_win": 93, "1_win": 107}
# {"i": 5500, "o_state": "5,2,3", "n_state": "3,2,3", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 20960, "0_win": 94, "1_win": 110}
# {"i": 5600, "o_state": "2,3,3", "n_state": "4,3,3", "a0": "MOVEAWAY", "a1": "MOVEAWAY", "t_re": 21369, "0_win": 96, "1_win": 112}
# {"i": 5700, "o_state": "4,3,3", "n_state": "4,3,3", "a0": "ATTACK", "a1": "ATTACK", "t_re": 21677, "0_win": 97, "1_win": 114}
# {"i": 5800, "o_state": "1,3,3", "n_state": "2,3,3", "a0": "MOVEAWAY", "a1": "ATTACK", "t_re": 21984, "0_win": 98, "1_win": 116}
# {"i": 5900, "o_state": "4,3,3", "n_state": "2,3,3", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 22499, "0_win": 100, "1_win": 119}
# {"i": 6000, "o_state": "2,1,1", "n_state": "1,1,1", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 22914, "0_win": 103, "1_win": 120}
# {"i": 6100, "o_state": "2,3,3", "n_state": "1,2,3", "a0": "MOVETOWARDS", "a1": "ATTACK", "t_re": 23323, "0_win": 105, "1_win": 122}
# {"i": 6200, "o_state": "5,2,3", "n_state": "4,2,3", "a0": "MOVETOWARDS", "a1": "ATTACK", "t_re": 23734, "0_win": 106, "1_win": 125}
# {"i": 6300, "o_state": "1,1,2", "n_state": "1,1,2", "a0": "MOVETOWARDS", "a1": "MOVEAWAY", "t_re": 23942, "0_win": 107, "1_win": 126}
# {"i": 6400, "o_state": "3,3,3", "n_state": "3,3,3", "a0": "MOVEAWAY", "a1": "MOVETOWARDS", "t_re": 24248, "0_win": 108, "1_win": 128}
# {"i": 6500, "o_state": "2,3,3", "n_state": "1,3,2", "a0": "ATTACK", "a1": "MOVETOWARDS", "t_re": 24558, "0_win": 110, "1_win": 129}
# {"i": 6600, "o_state": "3,3,3", "n_state": "1,3,3", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 24764, "0_win": 110, "1_win": 131}
# {"i": 6700, "o_state": "4,2,3", "n_state": "4,2,3", "a0": "ATTACK", "a1": "ATTACK", "t_re": 24971, "0_win": 112, "1_win": 131}
# {"i": 6800, "o_state": "3,1,2", "n_state": "2,1,2", "a0": "ATTACK", "a1": "MOVETOWARDS", "t_re": 25280, "0_win": 113, "1_win": 133}
# {"i": 6900, "o_state": "4,2,3", "n_state": "2,2,3", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 25793, "0_win": 117, "1_win": 134}
# {"i": 7000, "o_state": "5,3,3", "n_state": "5,3,3", "a0": "MOVEAWAY", "a1": "MOVEAWAY", "t_re": 25998, "0_win": 117, "1_win": 136}
# {"i": 7100, "o_state": "2,3,2", "n_state": "1,3,1", "a0": "ATTACK", "a1": "MOVETOWARDS", "t_re": 26413, "0_win": 120, "1_win": 137}
# {"i": 7200, "o_state": "2,2,2", "n_state": "1,2,1", "a0": "ATTACK", "a1": "MOVETOWARDS", "t_re": 26828, "0_win": 121, "1_win": 140}
# {"i": 7300, "o_state": "2,1,2", "n_state": "4,1,2", "a0": "MOVEAWAY", "a1": "MOVEAWAY", "t_re": 27035, "0_win": 123, "1_win": 140}
# {"i": 7400, "o_state": "2,2,3", "n_state": "1,1,3", "a0": "MOVETOWARDS", "a1": "ATTACK", "t_re": 27444, "0_win": 126, "1_win": 141}
# {"i": 7500, "o_state": "4,3,3", "n_state": "5,3,3", "a0": "MOVEAWAY", "a1": "ATTACK", "t_re": 27854, "0_win": 126, "1_win": 145}
# {"i": 7600, "o_state": "2,2,2", "n_state": "2,2,2", "a0": "ATTACK", "a1": "ATTACK", "t_re": 28061, "0_win": 128, "1_win": 145}
# {"i": 7700, "o_state": "2,1,1", "n_state": "1,1,1", "a0": "MOVETOWARDS", "a1": "ATTACK", "t_re": 28166, "0_win": 128, "1_win": 146}
# {"i": 7800, "o_state": "2,1,3", "n_state": "2,1,3", "a0": "ATTACK", "a1": "ATTACK", "t_re": 28576, "0_win": 130, "1_win": 148}
# {"i": 7900, "o_state": "4,1,1", "n_state": "2,1,1", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 28886, "0_win": 130, "1_win": 151}
# {"i": 8000, "o_state": "2,1,3", "n_state": "2,1,3", "a0": "MOVETOWARDS", "a1": "MOVEAWAY", "t_re": 29397, "0_win": 132, "1_win": 154}
# {"i": 8100, "o_state": "5,3,3", "n_state": "5,3,3", "a0": "MOVEAWAY", "a1": "MOVEAWAY", "t_re": 29910, "0_win": 132, "1_win": 159}
# {"i": 8200, "o_state": "2,3,3", "n_state": "2,3,3", "a0": "MOVETOWARDS", "a1": "MOVEAWAY", "t_re": 30218, "0_win": 135, "1_win": 159}
# {"i": 8300, "o_state": "3,2,3", "n_state": "1,2,3", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 30529, "0_win": 136, "1_win": 161}
# {"i": 8400, "o_state": "3,1,1", "n_state": "2,1,1", "a0": "ATTACK", "a1": "MOVETOWARDS", "t_re": 30735, "0_win": 136, "1_win": 163}
# {"i": 8500, "o_state": "1,1,2", "n_state": "2,1,2", "a0": "MOVEAWAY", "a1": "ATTACK", "t_re": 30939, "0_win": 138, "1_win": 163}
# {"i": 8600, "o_state": "4,2,3", "n_state": "2,2,3", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 31349, "0_win": 140, "1_win": 165}
# {"i": 8700, "o_state": "1,3,2", "n_state": "2,3,2", "a0": "ATTACK", "a1": "MOVEAWAY", "t_re": 31555, "0_win": 142, "1_win": 165}
# {"i": 8800, "o_state": "4,3,3", "n_state": "2,3,3", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 31964, "0_win": 143, "1_win": 168}
# {"i": 8900, "o_state": "2,3,3", "n_state": "1,3,2", "a0": "ATTACK", "a1": "MOVETOWARDS", "t_re": 32273, "0_win": 144, "1_win": 170}
# {"i": 9000, "o_state": "3,3,2", "n_state": "4,3,2", "a0": "ATTACK", "a1": "MOVEAWAY", "t_re": 32582, "0_win": 147, "1_win": 170}
# {"i": 9100, "o_state": "4,3,3", "n_state": "5,3,3", "a0": "MOVEAWAY", "a1": "ATTACK", "t_re": 32990, "0_win": 149, "1_win": 172}
# {"i": 9200, "o_state": "3,2,2", "n_state": "3,2,2", "a0": "MOVETOWARDS", "a1": "MOVEAWAY", "t_re": 33298, "0_win": 151, "1_win": 173}
# {"i": 9300, "o_state": "2,2,3", "n_state": "1,1,3", "a0": "MOVETOWARDS", "a1": "ATTACK", "t_re": 33709, "0_win": 152, "1_win": 176}
# {"i": 9400, "o_state": "3,3,3", "n_state": "3,3,3", "a0": "MOVEAWAY", "a1": "MOVETOWARDS", "t_re": 34118, "0_win": 155, "1_win": 177}
# {"i": 9500, "o_state": "3,1,2", "n_state": "2,1,2", "a0": "MOVETOWARDS", "a1": "ATTACK", "t_re": 34531, "0_win": 157, "1_win": 179}
# {"i": 9600, "o_state": "4,2,3", "n_state": "5,2,3", "a0": "MOVEAWAY", "a1": "ATTACK", "t_re": 34839, "0_win": 158, "1_win": 181}
# {"i": 9700, "o_state": "5,3,2", "n_state": "3,3,2", "a0": "MOVETOWARDS", "a1": "MOVETOWARDS", "t_re": 35149, "0_win": 159, "1_win": 183}
# {"i": 9800, "o_state": "2,1,3", "n_state": "2,1,3", "a0": "MOVETOWARDS", "a1": "MOVEAWAY", "t_re": 35664, "0_win": 161, "1_win": 186}
# {"i": 9900, "o_state": "5,3,3", "n_state": "5,3,3", "a0": "MOVEAWAY", "a1": "MOVETOWARDS", "t_re": 36176, "0_win": 162, "1_win": 190}
# {"i": 9999, "o_state": "2,1,1", "n_state": "2,1,1", "a0": "ATTACK", "a1": "ATTACK", "t_re": 36489, "0_win": 163, "1_win": 192}

# %%
agent = agent_1

for k in agent.q_dict:
    #if max(agent.q_dict[k]) > 0:
        print(json.dumps({"state": k, "action_reward": agent.q_dict[k]}))
# Out:
# {"state": "init", "action_reward": [0, 0, 0]}
# {"state": "2,3,3", "action_reward": [59.192142687799844, 56.65228233812724, 65.44567293450208]}
# {"state": "1,2,3", "action_reward": [69.15128893578579, 69.76665041855351, 78.59548100181057]}
# {"state": "2,2,3", "action_reward": [69.25138849436537, 63.82757891767544, 74.24422879961443]}
# {"state": "1,1,3", "action_reward": [82.99353329742051, 71.81920038223006, 88.15828459672574]}
# {"state": "2,1,3", "action_reward": [79.88893356331212, 61.08745423177678, 74.9794432740392]}
# {"state": "4,1,3", "action_reward": [60.243033819705346, 42.13384237451874, 39.46841279651556]}
# {"state": "5,1,3", "action_reward": [54.58499325816181, 21.35297968364941, 29.35571625960204]}
# {"state": "3,1,3", "action_reward": [76.19856113105766, 42.91057836084131, 59.174265295364116]}
# {"state": "1,0,3", "action_reward": [0, 0, 0]}
# {"state": "1,0,2", "action_reward": [0, 0, 0]}
# {"state": "4,3,3", "action_reward": [59.98392509352531, 52.674083582439515, 54.949421056311586]}
# {"state": "5,3,3", "action_reward": [54.91155025022429, 52.947001515554255, 54.92428919930892]}
# {"state": "3,3,3", "action_reward": [56.76049067723671, 54.32169719898571, 59.077245301610624]}
# {"state": "1,3,2", "action_reward": [34.251936669291425, 48.105951168982635, 55.617273397239245]}
# {"state": "2,3,2", "action_reward": [41.51952841201393, 46.95939718810058, 55.335450255695875]}
# {"state": "1,2,2", "action_reward": [56.022414337536944, 63.44340514002443, 75.76695592303481]}
# {"state": "2,2,2", "action_reward": [60.77047718946301, 62.03389135071946, 74.92301891636944]}
# {"state": "3,2,2", "action_reward": [67.51099719052183, 55.86372517770092, 60.556747518141826]}
# {"state": "1,2,1", "action_reward": [18.715127550897577, 50.51159438930571, 3.070664419459357]}
# {"state": "2,2,1", "action_reward": [-29.997620172177232, 43.953189533545206, 64.51134947694271]}
# {"state": "3,2,1", "action_reward": [43.153402050076785, 38.014127273313115, 44.024074046288945]}
# {"state": "4,2,1", "action_reward": [46.19455411124525, 33.01758470654585, 33.83614579717658]}
# {"state": "5,2,1", "action_reward": [36.08808365409736, 29.301413968665553, 35.07268200223517]}
# {"state": "1,1,1", "action_reward": [19.47727959949328, 75.38394461357254, 84.94626641997348]}
# {"state": "2,1,1", "action_reward": [11.55012187838771, 76.3599974986092, 93.00859382612647]}
# {"state": "1,0,1", "action_reward": [0, 0, 0]}
# {"state": "4,3,2", "action_reward": [46.45410023807007, 42.513662407065, 43.706560067930006]}
# {"state": "5,3,2", "action_reward": [44.24284876216859, 42.38281109054085, 41.21830751980767]}
# {"state": "3,3,2", "action_reward": [47.9281770440089, 43.62024087311212, 46.314584476369376]}
# {"state": "1,1,0", "action_reward": [0, 0, 0]}
# {"state": "1,3,3", "action_reward": [62.494731263553035, 58.31190375537034, 68.7195960332234]}
# {"state": "1,1,2", "action_reward": [76.87410172192254, 73.8847606654765, 86.58406746409132]}
# {"state": "4,2,2", "action_reward": [60.96950145647379, 50.46981030970594, 55.265954771300436]}
# {"state": "5,2,2", "action_reward": [57.69543907583137, 43.26292501587278, 49.74533171628955]}
# {"state": "4,1,1", "action_reward": [77.22806263304903, 60.414843615998976, 64.03710701687076]}
# {"state": "5,1,1", "action_reward": [67.27832032729935, 53.79957990630593, 52.41572543203375]}
# {"state": "3,1,1", "action_reward": [74.66199573174652, 67.0782643724965, 81.02538653593814]}
# {"state": "1,2,0", "action_reward": [0, 0, 0]}
# {"state": "3,1,2", "action_reward": [73.34959098157057, 66.70446622348784, 69.33431336125355]}
# {"state": "2,1,2", "action_reward": [74.87657608544, 69.25617674536844, 77.37565717669817]}
# {"state": "3,2,3", "action_reward": [69.99039280173331, 63.23413305226448, 64.85048054345766]}
# {"state": "1,3,1", "action_reward": [-58.65173139444078, 23.62230754528988, -16.230186011186312]}
# {"state": "2,3,1", "action_reward": [-52.23930626253734, 19.516233846094917, 23.547521422406973]}
# {"state": "4,3,1", "action_reward": [15.23712165774392, 3.0300824561057893, 2.2656246860561895]}
# {"state": "3,3,1", "action_reward": [21.02964537540544, 5.92798235129367, 16.319688139647507]}
# {"state": "1,3,0", "action_reward": [0, 0, 0]}
# {"state": "4,2,3", "action_reward": [66.29639778672056, 59.484775020853405, 60.231629278406174]}
# {"state": "5,2,3", "action_reward": [62.1169836566476, 56.89649464183125, 57.222947113524114]}
# {"state": "5,3,1", "action_reward": [5.254601639314602, 0.02748302750523407, 1.0741595993213564]}
# {"state": "4,1,2", "action_reward": [69.59695515954495, 64.63035774777457, 65.92356091431618]}
# {"state": "5,1,2", "action_reward": [66.6811472918624, 59.23951715822408, 56.21017048675846]}

# %%
agent_0.dump_qtable('agent_train_results/class1_f_class1_qtable_health3_distance2_agent0.txt')
agent_1.dump_qtable('agent_train_results/class1_f_class1_qtable_health3_distance2_agent1.txt')
# Out:
# {'1,0,1': [0, 0, 0],
#  '1,0,2': [0, 0, 0],
#  '1,0,3': [0, 0, 0],
#  '1,1,0': [0, 0, 0],
#  '1,1,1': [-2.275699636562667, 76.79297957747167, 60.0771497216827],
#  '1,1,2': [80.84136151873172, 79.86561660330482, 88.0045305065819],
#  '1,1,3': [81.53172710654489, 69.78442248335446, 89.57285545508955],
#  '1,2,0': [0, 0, 0],
#  '1,2,1': [-36.0215486258103, 44.08544553588937, -13.394185841663841],
#  '1,2,2': [54.35594310190142, 64.48191627869619, 76.82315114299134],
#  '1,2,3': [73.60243605674052, 65.62248410574226, 78.94397230451997],
#  '1,3,0': [0, 0, 0],
#  '1,3,1': [-47.746064101162986, 16.551592779218947, 2.5786318768098253],
#  '1,3,2': [43.21917713840395, 50.69484712644265, 59.1992745039743],
#  '1,3,3': [64.1073632276718, 62.9937394407941, 70.2950241393042],
#  '2,1,1': [8.074868078032573, 71.32975533327567, 82.41861813153588],
#  '2,1,2': [79.02272583752763, 73.38146271959127, 87.98928253993225],
#  '2,1,3': [82.8058206414583, 67.11766764820308, 73.60182195090086],
#  '2,2,1': [-37.19379482890021, 40.93945860871273, 49.54555942641394],
#  '2,2,2': [52.59224647675298, 60.869434716755826, 68.55323059677177],
#  '2,2,3': [71.9739142582939, 62.901259219099884, 70.48503831817547],
#  '2,3,1': [-6.151066584199497, 17.697520054038996, 32.89701230256157],
#  '2,3,2': [42.83334484052388, 47.3421492458159, 53.30397908950194],
#  '2,3,3': [60.5594696919065, 61.02197851708675, 66.58330926998468],
#  '3,1,1': [74.21349457125181, 68.57352688610456, 72.80942121155246],
#  '3,1,2': [80.62033326839632, 65.43855576310818, 74.92111781575467],
#  '3,1,3': [76.89582617854593, 60.284158489746694, 64.40920255001124],
#  '3,2,1': [41.64474138292944, 35.5649683984273, 39.64494322438706],
#  '3,2,2': [66.675814510455, 57.88790115989866, 59.2888529309609],
#  '3,2,3': [68.54309411578137, 57.37005982290399, 63.995718983384826],
#  '3,3,1': [18.669464574493837, 9.150552238716871, 13.650425338916135],
#  '3,3,2': [50.46468892861449, 42.474999252923, 48.51750708511388],
#  '3,3,3': [64.89368445015342, 59.94718701267917, 61.69800129734132],
#  '4,1,1': [72.97417477917102, 62.21873572775199, 66.88234973036289],
#  '4,1,2': [71.72762730452769, 60.11599558620299, 67.21952072349937],
#  '4,1,3': [67.86857196014546, 19.585241349504603, 35.76396953172343],
#  '4,2,1': [40.50331718592737, 29.813560375961064, 27.485680255395472],
#  '4,2,2': [60.368889916711794, 52.4175152258131, 58.66791534706807],
#  '4,2,3': [63.55055916561564, 47.83366012598455, 54.03215157477433],
#  '4,3,1': [16.852930883436816, 5.773255300218724, 6.93050483400701],
#  '4,3,2': [49.13764721901178, 44.48031240430133, 43.42222674342231],
#  '4,3,3': [62.1234330346118, 55.8501140650982, 60.09336829131179],
#  '5,1,1': [67.23109540483901, 55.79058546772589, 52.643205634807266],
#  '5,1,2': [68.68854071384389, 35.991565414747825, 49.93654868171381],
#  '5,1,3': [25.657355646070616, 30.143931375986984, 30.972271958262432],
#  '5,2,1': [35.05626953519191, 18.956436908874696, 28.3482338214743],
#  '5,2,2': [55.95079620091236, 31.350418555339665, 33.37117910760287],
#  '5,2,3': [58.214192203997264, 46.71528355197324, 45.62276092170001],
#  '5,3,1': [9.865658935502806, 7.443943825171977, 5.935389292599967],
#  '5,3,2': [45.044599088408354, 36.581518494415214, 27.669144673393895],
#  '5,3,3': [59.24083351054387, 54.31883516482941, 55.99940862519231],
#  'init': [0, 0, 0]}

# %%
import textwrap

def print_round(game_state, action_0, action_1):
    distance_gap = "".join(['.']*(game_state.agents_distance - 1))
    line = '{:<40s} {:<40s} {:<40s}'.format("Agent0: " + action_0, "Agent1: " + action_1, str(game_state.agents[0].health) + distance_gap + str(game_state.agents[1].health))
    print(line)

agent_0 = AgentClass1()
agent_1 = AgentClass1()

agent_0.load_qtable('agent_train_results/class1_f_class1_qtable_health3_distance2_agent0.txt')
agent_0.exploration_rate = 0

agent_1.load_qtable('agent_train_results/class1_f_class1_qtable_health3_distance2_agent1.txt')
agent_1.exploration_rate = 0

# %%
    
master.init_agents_distance = 3
master.reset()

print_round(master.state, "init", "init")

for step in range(100):
    old_state = copy.deepcopy(master.state) # Store current state
    
    action_0 = agent_0.get_next_action(old_state) # Query agent for the next action
    action_1 = agent_1.get_next_action(old_state)
        
    new_state, reward_0, reward_1 = master.take_action(action_0, action_1) # Take action, get new state and reward
    
    print_round(new_state, action_0, action_1)
        
    
    if master.is_finished() >= 0 :  # game is finished with winner
        break
# Out:
# Agent0: init                             Agent1: init                             3..3
# Agent0: MOVETOWARDS                      Agent1: MOVETOWARDS                      33
# Agent0: ATTACK                           Agent1: ATTACK                           23
# Agent0: ATTACK                           Agent1: ATTACK                           13
# Agent0: MOVEAWAY                         Agent1: ATTACK                           1.3
# Agent0: ATTACK                           Agent1: MOVETOWARDS                      12
# Agent0: MOVEAWAY                         Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2
# Agent0: ATTACK                           Agent1: ATTACK                           1.2

# %%
master.init_agents_distance = 3
master.reset()

print_round(master.state, "init", "init")

for step in range(100):
    old_state = copy.deepcopy(master.state) # Store current state
    
    action_0 = agent_0.get_next_action(old_state) # Query agent for the next action
    action_1 = agent_1.get_next_action(old_state)
        
    new_state, reward_0, reward_1 = master.take_action(action_0, action_1) # Take action, get new state and reward
    
    print_round(new_state, action_0, action_1)
        
    
    if master.is_finished() >= 0 :  # game is finished with winner
        break
# Out:
# Agent0: init                             Agent1: init                             3..3
# Agent0: MOVETOWARDS                      Agent1: MOVETOWARDS                      33
# Agent0: ATTACK                           Agent1: ATTACK                           22
# Agent0: ATTACK                           Agent1: ATTACK                           11
# Agent0: ATTACK                           Agent1: MOVEAWAY                         1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
# Agent0: ATTACK                           Agent1: ATTACK                           1.1
